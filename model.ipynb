# %% [markdown]
# # About this Notebook
# This notebook (`model.ipynb`) uses a step-by-step approach for model building and training, suitable for experimentation and manual tuning. It is ideal for users who want to understand and modify each stage of the model pipeline.

# %%
import random
import json
import numpy as np

# %%
intents = json.loads(open("intents.json").read())

# %%
intents
# Out:
# {'intents': [{'tag': 'greetings',
#    'patterns': ['Hello', 'Hey', 'Hi', 'Good Day', 'Greetings'],
#    'responses': ['Hello!', 'Hey', 'What Can I do for you?']},
#   {'tag': 'Acne',
#    'patterns': ['blackheads',
#     'pimples',
#     'face pimples',
#     'neck pimples',
#     'shoulder pimples'],
#    'responses': ['According to your symptoms you might have Acne',
#     'You have Acne',
#     'I suppose you have Acne']},
#   {'tag': 'Attention Deficit Disorder (ADHD)',
#    'patterns': ['impulsivity',
#     'hyperactivity',
#     'lack of focus',
#     'messy works',
#     'restlessness'],
#    'responses': ['According to your symptoms you might have Attention Deficit Disorder',
#     'You have Attention Deficit Disorder',
#     'I suppose you have Attention Deficit Disorder']},
#   {'tag': 'Allergies',
#    'patterns': ['sneezing',
#     'itchy eyes',
#     'coughing',
#     'watery eyes',
#     'itchy nose'],
#    'responses': ['According to your symptoms you might have Allergies',
#     'You have Allergies',
#     'I suppose you have Allergies']},
#   {'tag': 'Alzheimers',
#    'patterns': ['forgetful', 'confusion with time', 'poor judgement'],
#    'responses': ['According to your symptoms you might have Alzheimers',
#     'You have Alzheimers',
#     'I suppose you have Alzheimers']},
#   {'tag': 'Ankylosing Spondylitis',
#    'patterns': ['loss of appetite',
#     'weight loss',
#     'difficulty walking',
#     'pain in heels',
#     'pain in hips',
#     'pain in jaw',
#     'decreased energy',
#     'heart failure',
#     'heart block',
#     'pain in lower back',
#     'stiffness'],
#    'responses': ['According to your symptoms you might have Ankylosing Spondylitis',
#     'You have Ankylosing Spondylitis',
#     'I suppose you have Ankylosing Spondylitis']},
#   {'tag': 'Anorexia',
#    'patterns': ['terrifies of gaining weight',
#     'hard to sleep through night',
#     'dizziness',
#     'hair is falling out',
#     'constipation',
#     'swollen arms',
#     'swollen legs',
#     'fainting',
#     'underweight'],
#    'responses': ['According to your symptoms you might have Anorexia',
#     'You have Anorexia',
#     'I suppose you have Anorexia']},
#   {'tag': 'Anxiety or Panic Disorder',
#    'patterns': ['rapid heartbeat',
#     'fast heartbeat',
#     'sweating',
#     'shaking',
#     'shortness of breath',
#     'fear of death',
#     'chest pain',
#     'faintness'],
#    'responses': ['According to your symptoms you might have Anxiety or Panic Disorder',
#     'You have Anxiety or Panic Disorder',
#     'I suppose you have Panic Disorder']},
#   {'tag': 'Arthritis',
#    'patterns': ['lack of movement', 'sored area', 'joint pain'],
#    'responses': ['According to your symptoms you might have any type of Arthritis',
#     'You have any type of Arthritis',
#     'I suppose you have any type of Arthritis']},
#   {'tag': 'Antitrypsin Deficiency',
#    'patterns': ['jaundice',
#     'yellow skin',
#     'coughing up blood',
#     'yellow urine'],
#    'responses': ['According to your symptoms you might have Antitrypsin Deficiency',
#     'You have Antitrypsin Deficiency',
#     'I suppose you have Antitrypsin Deficiency']},
#   {'tag': 'Abdominal Migraine',
#    'patterns': ['dark shadows under eyes',
#     'be pale',
#     'have little energy',
#     'feeling drowsy',
#     'unable to eat'],
#    'responses': ['According to your symptoms you might have Abdominal Migraine',
#     'You have Abdominal Migraine',
#     'I suppose you have Abdominal Migraine']},
#   {'tag': 'Amyloidosis',
#    'patterns': ['sudden weight loss',
#     'feeling of fullness',
#     'shortness of breath',
#     'tongue swelling',
#     'severe fatigue',
#     'severe weakness',
#     'irregular heartbeat'],
#    'responses': ['According to your symptoms you might have Amyloidosis',
#     'You have Amyloidosis',
#     'I suppose you have Amyloidosis']},
#   {'tag': 'Abscessed Tooth',
#    'patterns': ['trouble swallowing',
#     'trouble breathing',
#     'bad taste',
#     'gum redness',
#     'sensitivity',
#     'bad odor in mouth'],
#    'responses': ['According to your symptoms you might have Abscessed Tooth',
#     'You have Abscessed Tooth',
#     'I suppose you have Abscessed Tooth']},
#   {'tag': 'Amenorrhea',
#    'patterns': ['hair loss',
#     'change in vision',
#     'hair growth on face',
#     'pain in pelvic area'],
#    'responses': ['According to your symptoms you might have Amenorrhea',
#     'You have Amenorrhea',
#     'I suppose you have Amenorrhea']},
#   {'tag': 'Absence Seizure',
#    'patterns': ['sudden stop in motion',
#     'lip smacking',
#     'eyelid fluttering',
#     'finger rubbing'],
#    'responses': ['According to your symptoms you might have Absence Seizure',
#     'You have Absence Seizure',
#     'I suppose you have Absence Seizure']},
#   {'tag': 'Sleep Apnea',
#    'patterns': ['loud snoring',
#     'loud gasping',
#     'loud choking',
#     'excessive sweating at night'],
#    'responses': ['According to your symptoms you might have Sleep Apnea',
#     'You have Sleep Apnea',
#     'I suppose you have Sleep Apnea']},
#   {'tag': 'Achalasia',
#    'patterns': ['food coming back up into the throat',
#     'nighttime coughing',
#     'heart is burning',
#     'hurt is belching'],
#    'responses': ['According to your symptoms you might have Achalasia',
#     'You have Achalasia',
#     'I suppose you have Achalasia']},
#   {'tag': 'Appendicitis',
#    'patterns': ['pain in lower belly',
#     'pain near navel',
#     'belly pain and vomiting',
#     'swollen belly',
#     'severe cramps',
#     'difficulty in peeing',
#     'constipation with gas'],
#    'responses': ['According to your symptoms you might have Appendicitis',
#     'You have Appendicitis',
#     'I suppose you have Appendicitis']},
#   {'tag': 'Aparaxia of Speech',
#    'patterns': ['unable to form proper words',
#     'unable to say complex words',
#     'speech inconsistencies',
#     'distortion in vowel sounds'],
#    'responses': ['According to your symptoms you might have Aparaxia of Speech',
#     'You have Aparaxia of Speech',
#     'I suppose you have Aparaxia of Speech']},
#   {'tag': 'Arachnoiditis',
#    'patterns': ['weakness in the legs',
#     'numbness in legs',
#     'ringing in ears',
#     'bladder problems'],
#    'responses': ['According to your symptoms you are suffering from Arachnoiditis',
#     'You have Arachnoiditis',
#     'I suppose you have Arachnoiditis']},
#   {'tag': 'Acute Respiratory Distress Syndrome (ARDS)',
#    'patterns': ['shortness of breath',
#     'low blood pressure',
#     'fast breathing',
#     'fast heartbeat',
#     'exhaustion',
#     'blue tinted lips',
#     'blue tinted nails'],
#    'responses': ['According to your symptoms you are suffering from Acute Respiratory Distress Syndrome (ARDS)',
#     'You have Acute Respiratory Distress Syndrome (ARDS)',
#     'I suppose you have Acute Respiratory Distress Syndrome (ARDS)']},
#   {'tag': 'Anemia',
#    'patterns': ['fatigue',
#     'weakness',
#     'pale skin',
#     'yellowish skin',
#     'shortness of breath',
#     'cold hands',
#     'cold feet'],
#    'responses': ['According to your symptoms you are suffering from Anemia',
#     'You have Anemia',
#     'I suppose you have Anemia']},
#   {'tag': 'Arrhythmia',
#    'patterns': ['palpitations',
#     'chest pounding',
#     'breath shortness',
#     'blurry vision',
#     'anxiety'],
#    'responses': ['According to your symptoms you might have Arrhythmia',
#     'You have Arrhythmia',
#     'I suppose you have Arrhythmia']},
#   {'tag': 'Asthma',
#    'patterns': ['coughing at night',
#     'wheezing',
#     'chest pain',
#     'frequent cough',
#     'feeling tired',
#     'easily upset',
#     'trouble in sleeping',
#     'pale face',
#     'sweaty face'],
#    'responses': ['According to your symptoms you might have Asthma',
#     'You have Asthma',
#     'I suppose you have Asthma']},
#   {'tag': 'Autism',
#    'patterns': ['delayed language',
#     'delayed learning',
#     'delayed movement',
#     'unusual mood',
#     'unusual eating habits',
#     'unusual sleeping habits',
#     'no facial expression'],
#    'responses': ['According to your symptoms you might have Autism',
#     'You have Autism',
#     'I suppose you have Autism']},
#   {'tag': 'Blepharitis',
#    'patterns': ['feels like something in the eye',
#     'a burning feeling in the eye',
#     'blurry vision',
#     'sensitivity to light',
#     'dry eyes',
#     'red eyes',
#     'watery eyes'],
#    'responses': ['According to your symptoms you might have Blepharitis',
#     'You have Blepharitis',
#     'I suppose you have Blepharitis']},
#   {'tag': 'Bacterial Arthritis',
#    'patterns': ['having chills',
#     'unable to move the limb with the infected joint',
#     'Severe pain in the affected joint'],
#    'responses': ['According to your symptoms you might have Bacterial Arthritis',
#     'You have Bacterial Arthritis',
#     'I suppose you have Backterial Arthritis']},
#   {'tag': 'Bacterial Meningitis',
#    'patterns': ['feeling confused',
#     'numbness in my face',
#     'neck is stiff',
#     'hard time concentrating',
#     'seizures',
#     'lack of appetite'],
#    'responses': ['According to your symptoms you might have Bacterial Meningitis',
#     'You have Meningitis',
#     'I suppose you have Meningitis']},
#   {'tag': 'Benign Prostate Enlargement(BPE)',
#    'patterns': ['makes it difficult o urinate',
#     'need to urinate frequently',
#     'wake up frequently in the night to urinate',
#     'difficulty in passing urine'],
#    'responses': ['According to your symptoms you might have Benign Prostate Enlargement Disease',
#     'You have Benign Prostate Enlargement Disease',
#     'I suppose you have Benign Prostate Enlargement Disease']},
#   {'tag': 'Bipolar Disorder',
#    'patterns': ['feeling depressed',
#     'lacking energy',
#     'loss of interest',
#     'feeling worthless',
#     'being pessimistic about everything',
#     'being delusional',
#     'suicidal thoughts',
#     'feeling full of energy',
#     'easily irritated'],
#    'responses': ['According to your symptoms you might have Bipolar Disorder Disease',
#     'You have Bipolar Disorder Disease',
#     'I suppose you have Bipolar Disorder Disease']},
#   {'tag': 'Bronchiectasis',
#    'patterns': ['persistent cough with large amount of phlegm',
#     'coughing up blood',
#     'coughing up blood-stained phlegm'],
#    'responses': ['According to your symptoms you might have Bronchiectasis Disease',
#     'You have Bronchiectasis Disease',
#     'I suppose you have Bronchiectasis Disease']},
#   {'tag': 'Bronchitis',
#    'patterns': ['blocked nose',
#     'runny or blocked nose',
#     'tiredness',
#     'cough with phlegm',
#     'cough with yellow gray phlegm'],
#    'responses': ['According to your symptoms you might have Bronchitis Disease',
#     'You have Bronchitis Disease',
#     'I suppose you have Bronchitis Disease']},
#   {'tag': 'Bulimia',
#    'patterns': ['over eating',
#     'think about food all time',
#     'overeats',
#     'focus in body image'],
#    'responses': ['According to your symptoms you might have Bulimia Disease',
#     'You have Bulimia Disease',
#     'I suppose you have Bulimia Disease']},
#   {'tag': 'Catarrh',
#    'patterns': ['constantly need to clear throat',
#     "blocked or stuffy nose can't clear",
#     'throat blocked',
#     'reduced sense of smell',
#     'reduced sense of taste',
#     'temporary hearing loss'],
#    'responses': ['According to your symptoms you might have Catarrh Disease',
#     'You have Catarrh Disease',
#     'I suppose you have Catarrh Disease']},
#   {'tag': 'Cellulitis',
#    'patterns': ['red skin', 'hot skin', 'swollen skin', 'tender skin'],
#    'responses': ['According to your symptoms you might have Cellulitis Disease',
#     'You have Cellulitis Disease',
#     'I suppose you have Cellulitis Disease']},
#   {'tag': 'Chest Infection',
#    'patterns': ['rapid heart beat', 'chest tightness', 'feeling confused'],
#    'responses': ['According to your symptoms you might have Chest Infection',
#     'You have Chest Infection',
#     'I suppose you have Chest Infection']},
#   {'tag': 'Chest Pain',
#    'patterns': ['chest feels heavy',
#     'chest feels tight',
#     'pain in chest and arms back and jaw',
#     'breathlessness'],
#    'responses': ['According to your symptoms you might have Chest Pain',
#     'You have Chest Pain',
#     'I suppose you have Chest Pain']},
#   {'tag': 'Chronic Fatigue Syndrome',
#    'patterns': ['sleep disturbance',
#     'poor temperature control',
#     'dizziness',
#     'hyper sensitive to light',
#     'hyper sensitive to sound',
#     'speech problem',
#     'language problem',
#     'problem with concentration',
#     'problem with thinking'],
#    'responses': ['According to your symptoms you might have Chronic Fatigue Syndrome',
#     'You have Chronic Fatigue Syndrome',
#     'I suppose you have Chronic Fatigue Syndrome']},
#   {'tag': 'Common Cold',
#    'patterns': ['sore throat',
#     'sneezing',
#     'coughing',
#     'hoarse voice',
#     'headache',
#     'ear ache',
#     'blocked nose',
#     'runny nose'],
#    'responses': ['According to your symptoms you might have Common Cold',
#     'You have Common Cold',
#     'I suppose you have Common Cold']},
#   {'tag': 'Conjunctivitis',
#    'patterns': ['eye redness',
#     'burning sensation in eyes',
#     'sticky coating on eye lashes',
#     'disturbed vision',
#     'intense red in eyes'],
#    'responses': ['According to your symptoms you might have Conjunctivitis',
#     'You have Conjunctivitis',
#     'I suppose you have Conjunctivitis']},
#   {'tag': 'Dehydration',
#    'patterns': ['light-headedness',
#     'tiredness',
#     'dry mouth',
#     'dry lips',
#     'infrequent urine'],
#    'responses': ['According to your symptoms you might have Dehydration',
#     'You have Dehydration',
#     'I suppose you have Dehydration']},
#   {'tag': 'Dental Abscess',
#    'patterns': ['intense pain in tooth',
#     'intense pain in gum',
#     'tooth pain spreads to ear jaw and neck',
#     'tender tooth',
#     'discoloured tooth',
#     'bad breath',
#     'sensitive to hot and cold'],
#    'responses': ['According to your symptoms you might have Dental Abscess',
#     'You have Dental Abscess',
#     'I suppose you have Dental Abscess']},
#   {'tag': 'Depression',
#    'patterns': ['continuous sadness',
#     'mood off',
#     'losing interest in things',
#     'losing motivation',
#     'feeling anxious',
#     'feeling guilty',
#     'feeling helpless',
#     'feeling hopeless',
#     'low self esteem',
#     'speaking slower than usual',
#     'feeling worried'],
#    'responses': ['According to your symptoms you might have Depression',
#     'You have Depression',
#     'I suppose you have Depression']},
#   {'tag': 'Diabetes',
#    'patterns': ['feeling very thirsty',
#     'loss of muscle bulk',
#     'feeling very tired',
#     'wounds heal slowly'],
#    'responses': ['According to your symptoms you might have Diabetes',
#     'You have Diabetes',
#     'I suppose you have Diabetes']},
#   {'tag': 'Diarrhoea',
#    'patterns': ['stomach cramps',
#     'pale skin',
#     'cold hands',
#     'cold feet',
#     'feeling drowsy',
#     'rapid heartbeat'],
#    'responses': ['According to your symptoms you might have Diarrhoea',
#     'You have Diarrhoea',
#     'I suppose you have Diarrhoea']},
#   {'tag': 'Dystonia',
#    'patterns': ['muscle spasms',
#     'abnormal posture',
#     'twisted posture',
#     'foot turning inwards',
#     'body parts jerking rapidly'],
#    'responses': ['According to your symptoms you might have Dystonia',
#     'You have Dystonia',
#     'I suppose you have Dystonia']},
#   {'tag': 'Epilepsy',
#    'patterns': ['experienced the events before',
#     'unusual smell or taste',
#     'tingling sensation in arms and legs',
#     'sudden feeling of fear or joy'],
#    'responses': ['According to your symptoms you might have Epilepsy',
#     'You have Epilepsy',
#     'I suppose you have Epilepsy']},
#   {'tag': 'Escherichia Coli',
#    'patterns': ['diarrhoea', 'stomach cramps', 'occasionally fever'],
#    'responses': ['According to your symptoms you might have Escherichia Coli',
#     'You have Escherichia Coli',
#     'I suppose you have Escherichia Coli']},
#   {'tag': 'Flu',
#    'patterns': ['sudden fever',
#     'dry cough',
#     'chesty cough',
#     'chills',
#     'aching muscles',
#     'sore throat'],
#    'responses': ['According to your symptoms you might have Flu',
#     'You have Flu',
#     'I suppose you have Flu']},
#   {'tag': 'Fetal alcohol spectrum disorder',
#    'patterns': ['hyperactivity',
#     'impulsivity',
#     'sensory difficulties',
#     'attention deficiency'],
#    'responses': ['According to your symptoms you might have Fetal alcohol spectrum disorder',
#     'You have Fetal alcohol spectrum disorder',
#     'I suppose you have Fetal alcohol spectrum disorder']},
#   {'tag': 'Food poisoning',
#    'patterns': ['nausea',
#     'diarrhoea',
#     'abdominal pain',
#     'chills',
#     'aching muscles',
#     'fever',
#     'stomach cramps',
#     'vomiting'],
#    'responses': ['According to your symptoms you might have Food poisoning',
#     'You have Food poisoning',
#     'I suppose you have Food poisoning']},
#   {'tag': 'Fungal nail infection',
#    'patterns': ['discolouration of the nail',
#     'brittle nails',
#     'crumbly nails',
#     'distorted nails'],
#    'responses': ['According to your symptoms you might have Fungal nail infection',
#     'You have Fungal nail infection',
#     'I suppose you have Fungal nail infection']},
#   {'tag': 'Gallbladder cancer',
#    'patterns': ['abdominal pain',
#     'stomach pain',
#     'jaundice',
#     'loss of appetite',
#     'swollen stomach',
#     'weight loss'],
#    'responses': ['According to your symptoms you might have Gallbladder cancer',
#     'You have Gallbladder cancer',
#     'I suppose you have Gallbladder cancer']},
#   {'tag': 'Gallstones',
#    'patterns': ['jaundice', 'persistent abdominal pain', 'fever'],
#    'responses': ['According to your symptoms you might have Gallstones',
#     'You have Gallstones',
#     'I suppose you have Gallstones']},
#   {'tag': 'Ganglion cyst',
#    'patterns': ['joint pain', 'cysts in wrist', 'swelling'],
#    'responses': ['According to your symptoms you might have Ganglion cyst',
#     'You have Ganglion cyst',
#     'I suppose you have Ganglion cyst']},
#   {'tag': 'Gastroenteritis',
#    'patterns': ['diarrhoea',
#     'vomiting',
#     'mild fever',
#     'aching limbs',
#     'headache',
#     'upset stomach',
#     'loss of appetite'],
#    'responses': ['According to your symptoms you might have Gastroenteritis',
#     'You have Gastroenteritis',
#     'I suppose you have Gastroenteritis']},
#   {'tag': 'Gastro-oesophageal reflux disease (GORD)',
#    'patterns': ['heartburn',
#     'bad breath',
#     'belching',
#     'acid reflux',
#     'pain when swallowing'],
#    'responses': ['According to your symptoms you might have Gastro-oesophageal reflux disease (GORD)',
#     'You have Gastro-oesophageal reflux disease (GORD)',
#     'I suppose you have Gastro-oesophageal reflux disease (GORD)']},
#   {'tag': 'Genital herpes',
#    'patterns': ['pain peeing',
#     'genital pain',
#     'swelling in groin',
#     'blisters',
#     'vaginal discharge',
#     'rectal pain'],
#    'responses': ['According to your symptoms you might have Genital herpes',
#     'You have Genital herpes',
#     'I suppose you have Genital herpes']},
#   {'tag': 'Genital warts',
#    'patterns': ['lumps around genitals',
#     'warts',
#     'vaginal outgrowth',
#     'lumps around penis'],
#    'responses': ['According to your symptoms you might have Genital warts',
#     'You have Genital warts',
#     'I suppose you have Genital warts']},
#   {'tag': 'Germ cell tumours',
#    'patterns': ['lump', 'olk-sac tumours'],
#    'responses': ['According to your symptoms you might have Germ cell tumours',
#     'You have Germ cell tumours',
#     'I suppose you have Germ cell tumours']},
#   {'tag': 'Glandular fever',
#    'patterns': ['fever',
#     'swollen glands',
#     'sore throat',
#     'fatigue',
#     'extreme tiredness'],
#    'responses': ['According to your symptoms you might have Glandular fever',
#     'You have Glandular fever',
#     'I suppose you have Glandular fever']},
#   {'tag': 'Gonorrhoea',
#    'patterns': ['pain while urinating',
#     'pain in lower abdomen',
#     'bleeding after sex',
#     'swelling of the testicles',
#     'yellow fluid discharge',
#     'increased vaginal discharge'],
#    'responses': ['According to your symptoms you might have Gonorrhoea',
#     'You have Gonorrhoea',
#     'I suppose you have Gonorrhoea']},
#   {'tag': 'Gout',
#    'patterns': ['joint pain',
#     'shiny skin over joints',
#     'swelling of joints',
#     'tender joints'],
#    'responses': ['According to your symptoms you might have Gout',
#     'You have Gout',
#     'I suppose you have Gout']},
#   {'tag': 'Gum disease',
#    'patterns': ['bad breath',
#     'bleeding in gums',
#     'swelling in gums',
#     'sore gums',
#     'bleeding while brushing'],
#    'responses': ['According to your symptoms you might have Gum disease',
#     'You have Gum disease',
#     'I suppose you have Gum disease']},
#   {'tag': 'Haemorrhoids (piles)',
#    'patterns': ['mucus discharge after passing a stool',
#     'itchy bottom',
#     'bleeding after defecating',
#     'soreness in anus',
#     'swelling around anus',
#     'redness around anus'],
#    'responses': ['According to your symptoms you might have Haemorrhoids (piles)',
#     'You have Haemorrhoids (piles)',
#     'I suppose you have Haemorrhoids (piles)']},
#   {'tag': 'Hand, foot and mouth disease',
#    'patterns': ['coughing',
#     'sore throat',
#     'sore mouth',
#     'loss of appetite',
#     'fever',
#     'abdominal pain',
#     'mouth ulcers',
#     'blisters',
#     'spotty rash'],
#    'responses': ['According to your symptoms you might have Hand, foot and mouth disease',
#     'You have Hand, foot and mouth disease',
#     'I suppose you have Hand, foot and mouth disease']},
#   {'tag': 'Hay fever',
#    'patterns': ['sneezing', 'itchy eyes', 'runny nose'],
#    'responses': ['According to your symptoms you might have Hay fever',
#     'You have Hay fever',
#     'I suppose you have Hay fever']},
#   {'tag': 'Head and neck cancer',
#    'patterns': ['persistent mouth ulcers',
#     'lump in mouth',
#     'persistent hoarseness',
#     'a persistent cough',
#     'lump or swelling in neck',
#     'shortness of breath',
#     'noisy breathing',
#     'difficulty or pain when swallowing',
#     'numbness in face',
#     'drooping on one side of face',
#     'nosebleeds',
#     'a persistent blocked nose',
#     'decreased sense of smell',
#     'hearing loss'],
#    'responses': ['According to your symptoms you might have Head and neck cancer',
#     'You have Head and neck cancer',
#     'I suppose you have Head and neck cancer']},
#   {'tag': 'Head lice and nits',
#    'patterns': ['itchy scalp',
#     'rash on the back of the neck',
#     'small white eggs or nits in the hair'],
#    'responses': ['According to your symptoms you might have Head lice and nits',
#     'You have Head lice and nits',
#     'I suppose you have Head lice and nits']},
#   {'tag': 'Headaches',
#    'patterns': ['stress',
#     'dehydration',
#     'nausea',
#     'vomiting',
#     'ncreased sensitivity to light or sound',
#     'watering or red eye',
#     'blocked or runny nose'],
#    'responses': ['According to your symptoms you might have Headaches',
#     'You have Headaches',
#     'I suppose you have Headaches']},
#   {'tag': 'Hearing loss',
#    'patterns': ['difficulty hearing',
#     'misunderstanding other people',
#     'asking people to repeat themselves'],
#    'responses': ['According to your symptoms you might have Hearing loss',
#     'You have Hearing loss',
#     'I suppose you have Hearing loss']},
#   {'tag': 'Heart failure',
#    'patterns': ['breathlessness',
#     'tiredness and lethargy',
#     'leg swelling',
#     'loss of appetite'],
#    'responses': ['According to your symptoms you might have Heart failure',
#     'You have Heart failure',
#     'I suppose you have Heart failure']},
#   {'tag': 'Hepatitis A',
#    'patterns': ['joint and muscle pain',
#     'fever',
#     'loss of appetite',
#     'itchy skin',
#     'dark urine',
#     'pale stools',
#     'jaundice',
#     'tiredness'],
#    'responses': ['According to your symptoms you might have Hepatitis A',
#     'You have Hepatitis A',
#     'I suppose you have Hepatitis A']},
#   {'tag': 'Hepatitis B',
#    'patterns': ['loss of appetite',
#     'diarrhoea',
#     'abdominal pain',
#     'tiredness',
#     'fever',
#     'flu'],
#    'responses': ['According to your symptoms you might have Hepatitis B',
#     'You have Hepatitis B',
#     'I suppose you have Hepatitis B']},
#   {'tag': 'Hepatitis C',
#    'patterns': ['tiredness',
#     'flu',
#     'loss of appetite',
#     'abdominal pain',
#     'muscle ache',
#     'fever'],
#    'responses': ['According to your symptoms you might have Hepatitis C',
#     'You have Hepatitis C',
#     'I suppose you have Hepatitis C']},
#   {'tag': 'Hiatus hernia',
#    'patterns': ['weak diaphragm',
#     'pressure on abdomen',
#     'leaking stomach acid',
#     'scarring on stomach'],
#    'responses': ['According to your symptoms you might have Hiatus hernia',
#     'You have Hiatus hernia',
#     'I suppose you have Hiatus hernia']},
#   {'tag': 'High cholesterol',
#    'patterns': ['overweight',
#     'high blood pressure',
#     'diabetes',
#     'stroke',
#     'heart attack'],
#    'responses': ['According to your symptoms you might have High cholesterol',
#     'You have High cholesterol',
#     'I suppose you have High cholesterol']},
#   {'tag': 'HIV',
#    'patterns': ['fever',
#     'swollen glands',
#     'rash',
#     'upset stomach',
#     'headache',
#     'muscle pain',
#     'joint pain'],
#    'responses': ['According to your symptoms you might have HIV',
#     'You have HIV',
#     'I suppose you have HIV']},
#   {'tag': "Huntington's disease",
#    'patterns': ['problem in movement',
#     'problem in cognition',
#     'mood swings',
#     'personality changes',
#     'irritability',
#     ''],
#    'responses': ["According to your symptoms you might have Huntington's disease",
#     "You have Huntington's disease",
#     "I suppose you have Huntington's disease",
#     'fidgety movements']},
#   {'tag': 'Hyperglycaemia (high blood sugar)',
#    'patterns': ['increased thirst',
#     'dry mouth',
#     'tiredness',
#     'blurred vision',
#     'unintentional weight loss',
#     'skin infection',
#     'thrush',
#     'recurrent infections',
#     'bladder infections',
#     'frequent urge to urinate'],
#    'responses': ['According to your symptoms you might have Hyperglycaemia (high blood sugar)',
#     'You have Hyperglycaemia (high blood sugar)',
#     'I suppose you have Hyperglycaemia (high blood sugar)']},
#   {'tag': 'Hyperhidrosis',
#    'patterns': ['excessive sweating',
#     'socially withdrawn',
#     'swelling in armpits',
#     'swelling in palms',
#     'swelling in groin',
#     'swelling in soles',
#     'swelling in face and chest'],
#    'responses': ['According to your symptoms you might have Hyperhidrosis',
#     'You have Hyperhidrosis',
#     'I suppose you have Hyperhidrosis']},
#   {'tag': 'Hypoglycaemia (low blood sugar)',
#    'patterns': ['hunger',
#     'trembling',
#     'shakiness',
#     'sweating',
#     'difficulty concentrating',
#     'disturbed sleep',
#     'confused upon waking'],
#    'responses': ['According to your symptoms you might have Hypoglycaemia (low blood sugar)',
#     'You have Hypoglycaemia (low blood sugar)',
#     'I suppose you have Hypoglycaemia (low blood sugar)']},
#   {'tag': 'Idiopathic pulmonary fibrosis',
#    'patterns': ['shortness of breath',
#     'tiredness',
#     'persistent dry cough',
#     'loss of appetite',
#     'loss of weight',
#     'swollen fingertips',
#     'clubbed fingers'],
#    'responses': ['According to your symptoms you might have Idiopathic pulmonary fibrosis',
#     'You have Idiopathic pulmonary fibrosis',
#     'I suppose you have Idiopathic pulmonary fibrosis']},
#   {'tag': 'Impetigo',
#    'patterns': ['red sores around nose',
#     'fever',
#     ' swollen glands',
#     'blisters'],
#    'responses': ['According to your symptoms you might have Impetigo',
#     'You have Impetigo',
#     'I suppose you have Impetigo']},
#   {'tag': 'Indigestion',
#    'patterns': ['bloatedness',
#     'belching',
#     'regurgitation',
#     'nausea',
#     'feeling full'],
#    'responses': ['According to your symptoms you might have Indigestion',
#     'You have Indigestion',
#     'I suppose you have Indigestion']},
#   {'tag': 'Ingrown toenail',
#    'patterns': ['inflammation in toe',
#     'yellow pus from toe',
#     'oedema',
#     'curling of nail'],
#    'responses': ['According to your symptoms you might have Ingrown toenail',
#     'You have Ingrown toenail',
#     'I suppose you have Ingrown toenail']},
#   {'tag': 'Inherited heart conditions',
#    'patterns': ['palpitations', 'fainting', 'blackouts'],
#    'responses': ['According to your symptoms you might have Inherited heart conditions',
#     'You have Inherited heart conditions',
#     'I suppose you have Inherited heart conditions']},
#   {'tag': 'Insomnia',
#    'patterns': ['difficulty in sleeping',
#     'awake for long periods',
#     'not feeling refreshed after waking',
#     'difficulty napping',
#     'difficulty concentrating',
#     'irritable'],
#    'responses': ['According to your symptoms you might have Insomnia',
#     'You have Insomnia',
#     'I suppose you have Insomnia']},
#   {'tag': 'Iron deficiency anaemia',
#    'patterns': ['tiredness',
#     'lethargy',
#     'lack of energy',
#     'shortness of breath',
#     'pale complexion',
#     'heart palpitations',
#     'headache',
#     'feeling itchy',
#     'difficulty swallowing',
#     'abnormally smooth tongue',
#     'hair loss'],
#    'responses': ['According to your symptoms you might have Iron deficiency anaemia',
#     'You have Iron deficiency anaemia',
#     'I suppose you have Iron deficiency anaemia']},
#   {'tag': 'Irritable bowel syndrome (IBS)',
#    'patterns': ['abdominal pain',
#     'diarrhoea',
#     'constipation',
#     'bloating',
#     'excessive flatulence',
#     'lethargy',
#     'heartburn',
#     'cramping'],
#    'responses': ['According to your symptoms you might have Irritable bowel syndrome (IBS)',
#     'You have Irritable bowel syndrome (IBS)',
#     'I suppose you have Irritable bowel syndrome (IBS)']},
#   {'tag': 'Irritable hip',
#    'patterns': ['slightly higher temperature',
#     'pain in the knee',
#     'thigh pain',
#     'estricted movement in hip joints',
#     'limping',
#     'hip pain'],
#    'responses': ['According to your symptoms you might have Irritable hip',
#     'You have Irritable hip',
#     'I suppose you have Irritable hip']},
#   {'tag': 'Itching',
#    'patterns': ['Redness',
#     'leathery or scaly patches',
#     'scratch marks',
#     'blisters',
#     'cracked skin',
#     'itchy skin',
#     'itchness all over body',
#     'dry skin',
#     'persistent itch'],
#    'responses': ['According to your symptoms you might have Itching',
#     'You have Itching',
#     'I suppose you have Itching']},
#   {'tag': 'Itchy bottom',
#    'patterns': ['persistent anal itch',
#     'anal bleeding',
#     'stool leakage',
#     'severe rectal itch',
#     'itchness in  bottom'],
#    'responses': ['According to your symptoms you might have Itchy bottom',
#     'You have Itchy bottom',
#     'I suppose you have Itchy bottom']},
#   {'tag': "Kaposi's sarcoma",
#    'patterns': ['uncomfortable swelling',
#     'nausea',
#     'vomiting',
#     '',
#     'coughing up blood',
#     'chest pain',
#     'stomach pain'],
#    'responses': ["According to your symptoms you might have Kaposi's sarcoma",
#     "You have Kaposi's sarcoma",
#     "I suppose you have Kaposi's sarcoma"]},
#   {'tag': 'Kidney infection',
#    'patterns': ['pus in kidney',
#     'shivering',
#     'pain in the back',
#     'painful urination',
#     'fever'],
#    'responses': ['According to your symptoms you might have Kidney infection',
#     'You have Kidney infection',
#     'I suppose you have Kidney infection']},
#   {'tag': 'Kidney stones',
#    'patterns': ['persistent ache in lower back',
#     'periods of intense pain',
#     'nausea',
#     'pain while urination',
#     'blood in urine',
#     'gfrequent urge to urinate',
#     'restlessness'],
#    'responses': ['According to your symptoms you might have Kidney stones',
#     'You have Kidney stones',
#     'I suppose you have Kidney stones']},
#   {'tag': 'Unknown',
#    'patterns': [],
#    'responses': ["Sorry I didn't understand what you said",
#     "Sorry I didn't catch that",
#     "Sorry I can't recognize you , Please try again"]},
#   {'tag': 'Goodbye',
#    'patterns': ['Thank You, Goodbye', 'See you', 'Bye', 'goodbye'],
#    'responses': ['Have a Nice day',
#     'Thank You to you too',
#     'Talk to you later!',
#     'GoodBye!']}]}

# %%
import sys
!"{sys.executable}" -m pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\ankit regmi\anaconda3\envs\tf_notebook\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\ankit regmi\anaconda3\envs\tf_notebook\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\ankit regmi\anaconda3\envs\tf_notebook\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ankit regmi\anaconda3\envs\tf_notebook\lib\site-packages (from nltk) (2025.7.34)
# Requirement already satisfied: tqdm in c:\users\ankit regmi\anaconda3\envs\tf_notebook\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\ankit regmi\anaconda3\envs\tf_notebook\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package english_wordnet to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package english_wordnet is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package mock_corpus to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mock_corpus is already up-to-date!
# [nltk_data]    | Downloading package moses_sample to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Ankit Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to C:\Users\Ankit
# [nltk_data]    |     Regmi\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
# from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

words = []
classes = []
documents = []
ignore_letters = ["?", "!", ".", ","]

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        word_list = [lemmatizer.lemmatize(word.lower()) for word in word_list if word not in ignore_letters]
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
    # if intent["tag"] not in classes:
    classes.append(intent["tag"])

# %%
classes
# Out:
# ['greetings',
#  'Acne',
#  'Attention Deficit Disorder (ADHD)',
#  'Allergies',
#  'Alzheimers',
#  'Ankylosing Spondylitis',
#  'Anorexia',
#  'Anxiety or Panic Disorder',
#  'Arthritis',
#  'Antitrypsin Deficiency',
#  'Abdominal Migraine',
#  'Amyloidosis',
#  'Abscessed Tooth',
#  'Amenorrhea',
#  'Absence Seizure',
#  'Sleep Apnea',
#  'Achalasia',
#  'Appendicitis',
#  'Aparaxia of Speech',
#  'Arachnoiditis',
#  'Acute Respiratory Distress Syndrome (ARDS)',
#  'Anemia',
#  'Arrhythmia',
#  'Asthma',
#  'Autism',
#  'Blepharitis',
#  'Bacterial Arthritis',
#  'Bacterial Meningitis',
#  'Benign Prostate Enlargement(BPE)',
#  'Bipolar Disorder',
#  'Bronchiectasis',
#  'Bronchitis',
#  'Bulimia',
#  'Catarrh',
#  'Cellulitis',
#  'Chest Infection',
#  'Chest Pain',
#  'Chronic Fatigue Syndrome',
#  'Common Cold',
#  'Conjunctivitis',
#  'Dehydration',
#  'Dental Abscess',
#  'Depression',
#  'Diabetes',
#  'Diarrhoea',
#  'Dystonia',
#  'Epilepsy',
#  'Escherichia Coli',
#  'Flu',
#  'Fetal alcohol spectrum disorder',
#  'Food poisoning',
#  'Fungal nail infection',
#  'Gallbladder cancer',
#  'Gallstones',
#  'Ganglion cyst',
#  'Gastroenteritis',
#  'Gastro-oesophageal reflux disease (GORD)',
#  'Genital herpes',
#  'Genital warts',
#  'Germ cell tumours',
#  'Glandular fever',
#  'Gonorrhoea',
#  'Gout',
#  'Gum disease',
#  'Haemorrhoids (piles)',
#  'Hand, foot and mouth disease',
#  'Hay fever',
#  'Head and neck cancer',
#  'Head lice and nits',
#  'Headaches',
#  'Hearing loss',
#  'Heart failure',
#  'Hepatitis A',
#  'Hepatitis B',
#  'Hepatitis C',
#  'Hiatus hernia',
#  'High cholesterol',
#  'HIV',
#  "Huntington's disease",
#  'Hyperglycaemia (high blood sugar)',
#  'Hyperhidrosis',
#  'Hypoglycaemia (low blood sugar)',
#  'Idiopathic pulmonary fibrosis',
#  'Impetigo',
#  'Indigestion',
#  'Ingrown toenail',
#  'Inherited heart conditions',
#  'Insomnia',
#  'Iron deficiency anaemia',
#  'Irritable bowel syndrome (IBS)',
#  'Irritable hip',
#  'Itching',
#  'Itchy bottom',
#  "Kaposi's sarcoma",
#  'Kidney infection',
#  'Kidney stones',
#  'Unknown',
#  'Goodbye']

# %%
# def get_wordnet_pos(word):
#     """Map POS tag to first character for lemmatizer"""
#     from nltk import pos_tag
#     tag = pos_tag([word])[0][1][0].upper()
#     tag_dict = {"J": wordnet.ADJ,
#                 "N": wordnet.NOUN,
#                 "V": wordnet.VERB,
#                 "R": wordnet.ADV}
#     return tag_dict.get(tag, wordnet.NOUN)

# %%
words = sorted(set(words))
classes = sorted(set(classes))

# %%
documents
# Out:
# [(['hello'], 'greetings'),
#  (['hey'], 'greetings'),
#  (['hi'], 'greetings'),
#  (['good', 'day'], 'greetings'),
#  (['greeting'], 'greetings'),
#  (['blackhead'], 'Acne'),
#  (['pimple'], 'Acne'),
#  (['face', 'pimple'], 'Acne'),
#  (['neck', 'pimple'], 'Acne'),
#  (['shoulder', 'pimple'], 'Acne'),
#  (['impulsivity'], 'Attention Deficit Disorder (ADHD)'),
#  (['hyperactivity'], 'Attention Deficit Disorder (ADHD)'),
#  (['lack', 'of', 'focus'], 'Attention Deficit Disorder (ADHD)'),
#  (['messy', 'work'], 'Attention Deficit Disorder (ADHD)'),
#  (['restlessness'], 'Attention Deficit Disorder (ADHD)'),
#  (['sneezing'], 'Allergies'),
#  (['itchy', 'eye'], 'Allergies'),
#  (['coughing'], 'Allergies'),
#  (['watery', 'eye'], 'Allergies'),
#  (['itchy', 'nose'], 'Allergies'),
#  (['forgetful'], 'Alzheimers'),
#  (['confusion', 'with', 'time'], 'Alzheimers'),
#  (['poor', 'judgement'], 'Alzheimers'),
#  (['loss', 'of', 'appetite'], 'Ankylosing Spondylitis'),
#  (['weight', 'loss'], 'Ankylosing Spondylitis'),
#  (['difficulty', 'walking'], 'Ankylosing Spondylitis'),
#  (['pain', 'in', 'heel'], 'Ankylosing Spondylitis'),
#  (['pain', 'in', 'hip'], 'Ankylosing Spondylitis'),
#  (['pain', 'in', 'jaw'], 'Ankylosing Spondylitis'),
#  (['decreased', 'energy'], 'Ankylosing Spondylitis'),
#  (['heart', 'failure'], 'Ankylosing Spondylitis'),
#  (['heart', 'block'], 'Ankylosing Spondylitis'),
#  (['pain', 'in', 'lower', 'back'], 'Ankylosing Spondylitis'),
#  (['stiffness'], 'Ankylosing Spondylitis'),
#  (['terrifies', 'of', 'gaining', 'weight'], 'Anorexia'),
#  (['hard', 'to', 'sleep', 'through', 'night'], 'Anorexia'),
#  (['dizziness'], 'Anorexia'),
#  (['hair', 'is', 'falling', 'out'], 'Anorexia'),
#  (['constipation'], 'Anorexia'),
#  (['swollen', 'arm'], 'Anorexia'),
#  (['swollen', 'leg'], 'Anorexia'),
#  (['fainting'], 'Anorexia'),
#  (['underweight'], 'Anorexia'),
#  (['rapid', 'heartbeat'], 'Anxiety or Panic Disorder'),
#  (['fast', 'heartbeat'], 'Anxiety or Panic Disorder'),
#  (['sweating'], 'Anxiety or Panic Disorder'),
#  (['shaking'], 'Anxiety or Panic Disorder'),
#  (['shortness', 'of', 'breath'], 'Anxiety or Panic Disorder'),
#  (['fear', 'of', 'death'], 'Anxiety or Panic Disorder'),
#  (['chest', 'pain'], 'Anxiety or Panic Disorder'),
#  (['faintness'], 'Anxiety or Panic Disorder'),
#  (['lack', 'of', 'movement'], 'Arthritis'),
#  (['sored', 'area'], 'Arthritis'),
#  (['joint', 'pain'], 'Arthritis'),
#  (['jaundice'], 'Antitrypsin Deficiency'),
#  (['yellow', 'skin'], 'Antitrypsin Deficiency'),
#  (['coughing', 'up', 'blood'], 'Antitrypsin Deficiency'),
#  (['yellow', 'urine'], 'Antitrypsin Deficiency'),
#  (['dark', 'shadow', 'under', 'eye'], 'Abdominal Migraine'),
#  (['be', 'pale'], 'Abdominal Migraine'),
#  (['have', 'little', 'energy'], 'Abdominal Migraine'),
#  (['feeling', 'drowsy'], 'Abdominal Migraine'),
#  (['unable', 'to', 'eat'], 'Abdominal Migraine'),
#  (['sudden', 'weight', 'loss'], 'Amyloidosis'),
#  (['feeling', 'of', 'fullness'], 'Amyloidosis'),
#  (['shortness', 'of', 'breath'], 'Amyloidosis'),
#  (['tongue', 'swelling'], 'Amyloidosis'),
#  (['severe', 'fatigue'], 'Amyloidosis'),
#  (['severe', 'weakness'], 'Amyloidosis'),
#  (['irregular', 'heartbeat'], 'Amyloidosis'),
#  (['trouble', 'swallowing'], 'Abscessed Tooth'),
#  (['trouble', 'breathing'], 'Abscessed Tooth'),
#  (['bad', 'taste'], 'Abscessed Tooth'),
#  (['gum', 'redness'], 'Abscessed Tooth'),
#  (['sensitivity'], 'Abscessed Tooth'),
#  (['bad', 'odor', 'in', 'mouth'], 'Abscessed Tooth'),
#  (['hair', 'loss'], 'Amenorrhea'),
#  (['change', 'in', 'vision'], 'Amenorrhea'),
#  (['hair', 'growth', 'on', 'face'], 'Amenorrhea'),
#  (['pain', 'in', 'pelvic', 'area'], 'Amenorrhea'),
#  (['sudden', 'stop', 'in', 'motion'], 'Absence Seizure'),
#  (['lip', 'smacking'], 'Absence Seizure'),
#  (['eyelid', 'fluttering'], 'Absence Seizure'),
#  (['finger', 'rubbing'], 'Absence Seizure'),
#  (['loud', 'snoring'], 'Sleep Apnea'),
#  (['loud', 'gasping'], 'Sleep Apnea'),
#  (['loud', 'choking'], 'Sleep Apnea'),
#  (['excessive', 'sweating', 'at', 'night'], 'Sleep Apnea'),
#  (['food', 'coming', 'back', 'up', 'into', 'the', 'throat'], 'Achalasia'),
#  (['nighttime', 'coughing'], 'Achalasia'),
#  (['heart', 'is', 'burning'], 'Achalasia'),
#  (['hurt', 'is', 'belching'], 'Achalasia'),
#  (['pain', 'in', 'lower', 'belly'], 'Appendicitis'),
#  (['pain', 'near', 'navel'], 'Appendicitis'),
#  (['belly', 'pain', 'and', 'vomiting'], 'Appendicitis'),
#  (['swollen', 'belly'], 'Appendicitis'),
#  (['severe', 'cramp'], 'Appendicitis'),
#  (['difficulty', 'in', 'peeing'], 'Appendicitis'),
#  (['constipation', 'with', 'gas'], 'Appendicitis'),
#  (['unable', 'to', 'form', 'proper', 'word'], 'Aparaxia of Speech'),
#  (['unable', 'to', 'say', 'complex', 'word'], 'Aparaxia of Speech'),
#  (['speech', 'inconsistency'], 'Aparaxia of Speech'),
#  (['distortion', 'in', 'vowel', 'sound'], 'Aparaxia of Speech'),
#  (['weakness', 'in', 'the', 'leg'], 'Arachnoiditis'),
#  (['numbness', 'in', 'leg'], 'Arachnoiditis'),
#  (['ringing', 'in', 'ear'], 'Arachnoiditis'),
#  (['bladder', 'problem'], 'Arachnoiditis'),
#  (['shortness', 'of', 'breath'], 'Acute Respiratory Distress Syndrome (ARDS)'),
#  (['low', 'blood', 'pressure'], 'Acute Respiratory Distress Syndrome (ARDS)'),
#  (['fast', 'breathing'], 'Acute Respiratory Distress Syndrome (ARDS)'),
#  (['fast', 'heartbeat'], 'Acute Respiratory Distress Syndrome (ARDS)'),
#  (['exhaustion'], 'Acute Respiratory Distress Syndrome (ARDS)'),
#  (['blue', 'tinted', 'lip'], 'Acute Respiratory Distress Syndrome (ARDS)'),
#  (['blue', 'tinted', 'nail'], 'Acute Respiratory Distress Syndrome (ARDS)'),
#  (['fatigue'], 'Anemia'),
#  (['weakness'], 'Anemia'),
#  (['pale', 'skin'], 'Anemia'),
#  (['yellowish', 'skin'], 'Anemia'),
#  (['shortness', 'of', 'breath'], 'Anemia'),
#  (['cold', 'hand'], 'Anemia'),
#  (['cold', 'foot'], 'Anemia'),
#  (['palpitation'], 'Arrhythmia'),
#  (['chest', 'pounding'], 'Arrhythmia'),
#  (['breath', 'shortness'], 'Arrhythmia'),
#  (['blurry', 'vision'], 'Arrhythmia'),
#  (['anxiety'], 'Arrhythmia'),
#  (['coughing', 'at', 'night'], 'Asthma'),
#  (['wheezing'], 'Asthma'),
#  (['chest', 'pain'], 'Asthma'),
#  (['frequent', 'cough'], 'Asthma'),
#  (['feeling', 'tired'], 'Asthma'),
#  (['easily', 'upset'], 'Asthma'),
#  (['trouble', 'in', 'sleeping'], 'Asthma'),
#  (['pale', 'face'], 'Asthma'),
#  (['sweaty', 'face'], 'Asthma'),
#  (['delayed', 'language'], 'Autism'),
#  (['delayed', 'learning'], 'Autism'),
#  (['delayed', 'movement'], 'Autism'),
#  (['unusual', 'mood'], 'Autism'),
#  (['unusual', 'eating', 'habit'], 'Autism'),
#  (['unusual', 'sleeping', 'habit'], 'Autism'),
#  (['no', 'facial', 'expression'], 'Autism'),
#  (['feel', 'like', 'something', 'in', 'the', 'eye'], 'Blepharitis'),
#  (['a', 'burning', 'feeling', 'in', 'the', 'eye'], 'Blepharitis'),
#  (['blurry', 'vision'], 'Blepharitis'),
#  (['sensitivity', 'to', 'light'], 'Blepharitis'),
#  (['dry', 'eye'], 'Blepharitis'),
#  (['red', 'eye'], 'Blepharitis'),
#  (['watery', 'eye'], 'Blepharitis'),
#  (['having', 'chill'], 'Bacterial Arthritis'),
#  (['unable', 'to', 'move', 'the', 'limb', 'with', 'the', 'infected', 'joint'],
#   'Bacterial Arthritis'),
#  (['severe', 'pain', 'in', 'the', 'affected', 'joint'], 'Bacterial Arthritis'),
#  (['feeling', 'confused'], 'Bacterial Meningitis'),
#  (['numbness', 'in', 'my', 'face'], 'Bacterial Meningitis'),
#  (['neck', 'is', 'stiff'], 'Bacterial Meningitis'),
#  (['hard', 'time', 'concentrating'], 'Bacterial Meningitis'),
#  (['seizure'], 'Bacterial Meningitis'),
#  (['lack', 'of', 'appetite'], 'Bacterial Meningitis'),
#  (['make', 'it', 'difficult', 'o', 'urinate'],
#   'Benign Prostate Enlargement(BPE)'),
#  (['need', 'to', 'urinate', 'frequently'], 'Benign Prostate Enlargement(BPE)'),
#  (['wake', 'up', 'frequently', 'in', 'the', 'night', 'to', 'urinate'],
#   'Benign Prostate Enlargement(BPE)'),
#  (['difficulty', 'in', 'passing', 'urine'],
#   'Benign Prostate Enlargement(BPE)'),
#  (['feeling', 'depressed'], 'Bipolar Disorder'),
#  (['lacking', 'energy'], 'Bipolar Disorder'),
#  (['loss', 'of', 'interest'], 'Bipolar Disorder'),
#  (['feeling', 'worthless'], 'Bipolar Disorder'),
#  (['being', 'pessimistic', 'about', 'everything'], 'Bipolar Disorder'),
#  (['being', 'delusional'], 'Bipolar Disorder'),
#  (['suicidal', 'thought'], 'Bipolar Disorder'),
#  (['feeling', 'full', 'of', 'energy'], 'Bipolar Disorder'),
#  (['easily', 'irritated'], 'Bipolar Disorder'),
#  (['persistent', 'cough', 'with', 'large', 'amount', 'of', 'phlegm'],
#   'Bronchiectasis'),
#  (['coughing', 'up', 'blood'], 'Bronchiectasis'),
#  (['coughing', 'up', 'blood-stained', 'phlegm'], 'Bronchiectasis'),
#  (['blocked', 'nose'], 'Bronchitis'),
#  (['runny', 'or', 'blocked', 'nose'], 'Bronchitis'),
#  (['tiredness'], 'Bronchitis'),
#  (['cough', 'with', 'phlegm'], 'Bronchitis'),
#  (['cough', 'with', 'yellow', 'gray', 'phlegm'], 'Bronchitis'),
#  (['over', 'eating'], 'Bulimia'),
#  (['think', 'about', 'food', 'all', 'time'], 'Bulimia'),
#  (['overeats'], 'Bulimia'),
#  (['focus', 'in', 'body', 'image'], 'Bulimia'),
#  (['constantly', 'need', 'to', 'clear', 'throat'], 'Catarrh'),
#  (['blocked', 'or', 'stuffy', 'nose', 'ca', "n't", 'clear'], 'Catarrh'),
#  (['throat', 'blocked'], 'Catarrh'),
#  (['reduced', 'sense', 'of', 'smell'], 'Catarrh'),
#  (['reduced', 'sense', 'of', 'taste'], 'Catarrh'),
#  (['temporary', 'hearing', 'loss'], 'Catarrh'),
#  (['red', 'skin'], 'Cellulitis'),
#  (['hot', 'skin'], 'Cellulitis'),
#  (['swollen', 'skin'], 'Cellulitis'),
#  (['tender', 'skin'], 'Cellulitis'),
#  (['rapid', 'heart', 'beat'], 'Chest Infection'),
#  (['chest', 'tightness'], 'Chest Infection'),
#  (['feeling', 'confused'], 'Chest Infection'),
#  (['chest', 'feel', 'heavy'], 'Chest Pain'),
#  (['chest', 'feel', 'tight'], 'Chest Pain'),
#  (['pain', 'in', 'chest', 'and', 'arm', 'back', 'and', 'jaw'], 'Chest Pain'),
#  (['breathlessness'], 'Chest Pain'),
#  (['sleep', 'disturbance'], 'Chronic Fatigue Syndrome'),
#  (['poor', 'temperature', 'control'], 'Chronic Fatigue Syndrome'),
#  (['dizziness'], 'Chronic Fatigue Syndrome'),
#  (['hyper', 'sensitive', 'to', 'light'], 'Chronic Fatigue Syndrome'),
#  (['hyper', 'sensitive', 'to', 'sound'], 'Chronic Fatigue Syndrome'),
#  (['speech', 'problem'], 'Chronic Fatigue Syndrome'),
#  (['language', 'problem'], 'Chronic Fatigue Syndrome'),
#  (['problem', 'with', 'concentration'], 'Chronic Fatigue Syndrome'),
#  (['problem', 'with', 'thinking'], 'Chronic Fatigue Syndrome'),
#  (['sore', 'throat'], 'Common Cold'),
#  (['sneezing'], 'Common Cold'),
#  (['coughing'], 'Common Cold'),
#  (['hoarse', 'voice'], 'Common Cold'),
#  (['headache'], 'Common Cold'),
#  (['ear', 'ache'], 'Common Cold'),
#  (['blocked', 'nose'], 'Common Cold'),
#  (['runny', 'nose'], 'Common Cold'),
#  (['eye', 'redness'], 'Conjunctivitis'),
#  (['burning', 'sensation', 'in', 'eye'], 'Conjunctivitis'),
#  (['sticky', 'coating', 'on', 'eye', 'lash'], 'Conjunctivitis'),
#  (['disturbed', 'vision'], 'Conjunctivitis'),
#  (['intense', 'red', 'in', 'eye'], 'Conjunctivitis'),
#  (['light-headedness'], 'Dehydration'),
#  (['tiredness'], 'Dehydration'),
#  (['dry', 'mouth'], 'Dehydration'),
#  (['dry', 'lip'], 'Dehydration'),
#  (['infrequent', 'urine'], 'Dehydration'),
#  (['intense', 'pain', 'in', 'tooth'], 'Dental Abscess'),
#  (['intense', 'pain', 'in', 'gum'], 'Dental Abscess'),
#  (['tooth', 'pain', 'spread', 'to', 'ear', 'jaw', 'and', 'neck'],
#   'Dental Abscess'),
#  (['tender', 'tooth'], 'Dental Abscess'),
#  (['discoloured', 'tooth'], 'Dental Abscess'),
#  (['bad', 'breath'], 'Dental Abscess'),
#  (['sensitive', 'to', 'hot', 'and', 'cold'], 'Dental Abscess'),
#  (['continuous', 'sadness'], 'Depression'),
#  (['mood', 'off'], 'Depression'),
#  (['losing', 'interest', 'in', 'thing'], 'Depression'),
#  (['losing', 'motivation'], 'Depression'),
#  (['feeling', 'anxious'], 'Depression'),
#  (['feeling', 'guilty'], 'Depression'),
#  (['feeling', 'helpless'], 'Depression'),
#  (['feeling', 'hopeless'], 'Depression'),
#  (['low', 'self', 'esteem'], 'Depression'),
#  (['speaking', 'slower', 'than', 'usual'], 'Depression'),
#  (['feeling', 'worried'], 'Depression'),
#  (['feeling', 'very', 'thirsty'], 'Diabetes'),
#  (['loss', 'of', 'muscle', 'bulk'], 'Diabetes'),
#  (['feeling', 'very', 'tired'], 'Diabetes'),
#  (['wound', 'heal', 'slowly'], 'Diabetes'),
#  (['stomach', 'cramp'], 'Diarrhoea'),
#  (['pale', 'skin'], 'Diarrhoea'),
#  (['cold', 'hand'], 'Diarrhoea'),
#  (['cold', 'foot'], 'Diarrhoea'),
#  (['feeling', 'drowsy'], 'Diarrhoea'),
#  (['rapid', 'heartbeat'], 'Diarrhoea'),
#  (['muscle', 'spasm'], 'Dystonia'),
#  (['abnormal', 'posture'], 'Dystonia'),
#  (['twisted', 'posture'], 'Dystonia'),
#  (['foot', 'turning', 'inwards'], 'Dystonia'),
#  (['body', 'part', 'jerking', 'rapidly'], 'Dystonia'),
#  (['experienced', 'the', 'event', 'before'], 'Epilepsy'),
#  (['unusual', 'smell', 'or', 'taste'], 'Epilepsy'),
#  (['tingling', 'sensation', 'in', 'arm', 'and', 'leg'], 'Epilepsy'),
#  (['sudden', 'feeling', 'of', 'fear', 'or', 'joy'], 'Epilepsy'),
#  (['diarrhoea'], 'Escherichia Coli'),
#  (['stomach', 'cramp'], 'Escherichia Coli'),
#  (['occasionally', 'fever'], 'Escherichia Coli'),
#  (['sudden', 'fever'], 'Flu'),
#  (['dry', 'cough'], 'Flu'),
#  (['chesty', 'cough'], 'Flu'),
#  (['chill'], 'Flu'),
#  (['aching', 'muscle'], 'Flu'),
#  (['sore', 'throat'], 'Flu'),
#  (['hyperactivity'], 'Fetal alcohol spectrum disorder'),
#  (['impulsivity'], 'Fetal alcohol spectrum disorder'),
#  (['sensory', 'difficulty'], 'Fetal alcohol spectrum disorder'),
#  (['attention', 'deficiency'], 'Fetal alcohol spectrum disorder'),
#  (['nausea'], 'Food poisoning'),
#  (['diarrhoea'], 'Food poisoning'),
#  (['abdominal', 'pain'], 'Food poisoning'),
#  (['chill'], 'Food poisoning'),
#  (['aching', 'muscle'], 'Food poisoning'),
#  (['fever'], 'Food poisoning'),
#  (['stomach', 'cramp'], 'Food poisoning'),
#  (['vomiting'], 'Food poisoning'),
#  (['discolouration', 'of', 'the', 'nail'], 'Fungal nail infection'),
#  (['brittle', 'nail'], 'Fungal nail infection'),
#  (['crumbly', 'nail'], 'Fungal nail infection'),
#  (['distorted', 'nail'], 'Fungal nail infection'),
#  (['abdominal', 'pain'], 'Gallbladder cancer'),
#  (['stomach', 'pain'], 'Gallbladder cancer'),
#  (['jaundice'], 'Gallbladder cancer'),
#  (['loss', 'of', 'appetite'], 'Gallbladder cancer'),
#  (['swollen', 'stomach'], 'Gallbladder cancer'),
#  (['weight', 'loss'], 'Gallbladder cancer'),
#  (['jaundice'], 'Gallstones'),
#  (['persistent', 'abdominal', 'pain'], 'Gallstones'),
#  (['fever'], 'Gallstones'),
#  (['joint', 'pain'], 'Ganglion cyst'),
#  (['cyst', 'in', 'wrist'], 'Ganglion cyst'),
#  (['swelling'], 'Ganglion cyst'),
#  (['diarrhoea'], 'Gastroenteritis'),
#  (['vomiting'], 'Gastroenteritis'),
#  (['mild', 'fever'], 'Gastroenteritis'),
#  (['aching', 'limb'], 'Gastroenteritis'),
#  (['headache'], 'Gastroenteritis'),
#  (['upset', 'stomach'], 'Gastroenteritis'),
#  (['loss', 'of', 'appetite'], 'Gastroenteritis'),
#  (['heartburn'], 'Gastro-oesophageal reflux disease (GORD)'),
#  (['bad', 'breath'], 'Gastro-oesophageal reflux disease (GORD)'),
#  (['belching'], 'Gastro-oesophageal reflux disease (GORD)'),
#  (['acid', 'reflux'], 'Gastro-oesophageal reflux disease (GORD)'),
#  (['pain', 'when', 'swallowing'], 'Gastro-oesophageal reflux disease (GORD)'),
#  (['pain', 'peeing'], 'Genital herpes'),
#  (['genital', 'pain'], 'Genital herpes'),
#  (['swelling', 'in', 'groin'], 'Genital herpes'),
#  (['blister'], 'Genital herpes'),
#  (['vaginal', 'discharge'], 'Genital herpes'),
#  (['rectal', 'pain'], 'Genital herpes'),
#  (['lump', 'around', 'genitals'], 'Genital warts'),
#  (['wart'], 'Genital warts'),
#  (['vaginal', 'outgrowth'], 'Genital warts'),
#  (['lump', 'around', 'penis'], 'Genital warts'),
#  (['lump'], 'Germ cell tumours'),
#  (['olk-sac', 'tumour'], 'Germ cell tumours'),
#  (['fever'], 'Glandular fever'),
#  (['swollen', 'gland'], 'Glandular fever'),
#  (['sore', 'throat'], 'Glandular fever'),
#  (['fatigue'], 'Glandular fever'),
#  (['extreme', 'tiredness'], 'Glandular fever'),
#  (['pain', 'while', 'urinating'], 'Gonorrhoea'),
#  (['pain', 'in', 'lower', 'abdomen'], 'Gonorrhoea'),
#  (['bleeding', 'after', 'sex'], 'Gonorrhoea'),
#  (['swelling', 'of', 'the', 'testicle'], 'Gonorrhoea'),
#  (['yellow', 'fluid', 'discharge'], 'Gonorrhoea'),
#  (['increased', 'vaginal', 'discharge'], 'Gonorrhoea'),
#  (['joint', 'pain'], 'Gout'),
#  (['shiny', 'skin', 'over', 'joint'], 'Gout'),
#  (['swelling', 'of', 'joint'], 'Gout'),
#  (['tender', 'joint'], 'Gout'),
#  (['bad', 'breath'], 'Gum disease'),
#  (['bleeding', 'in', 'gum'], 'Gum disease'),
#  (['swelling', 'in', 'gum'], 'Gum disease'),
#  (['sore', 'gum'], 'Gum disease'),
#  (['bleeding', 'while', 'brushing'], 'Gum disease'),
#  (['mucus', 'discharge', 'after', 'passing', 'a', 'stool'],
#   'Haemorrhoids (piles)'),
#  (['itchy', 'bottom'], 'Haemorrhoids (piles)'),
#  (['bleeding', 'after', 'defecating'], 'Haemorrhoids (piles)'),
#  (['soreness', 'in', 'anus'], 'Haemorrhoids (piles)'),
#  (['swelling', 'around', 'anus'], 'Haemorrhoids (piles)'),
#  (['redness', 'around', 'anus'], 'Haemorrhoids (piles)'),
#  (['coughing'], 'Hand, foot and mouth disease'),
#  (['sore', 'throat'], 'Hand, foot and mouth disease'),
#  (['sore', 'mouth'], 'Hand, foot and mouth disease'),
#  (['loss', 'of', 'appetite'], 'Hand, foot and mouth disease'),
#  (['fever'], 'Hand, foot and mouth disease'),
#  (['abdominal', 'pain'], 'Hand, foot and mouth disease'),
#  (['mouth', 'ulcer'], 'Hand, foot and mouth disease'),
#  (['blister'], 'Hand, foot and mouth disease'),
#  (['spotty', 'rash'], 'Hand, foot and mouth disease'),
#  (['sneezing'], 'Hay fever'),
#  (['itchy', 'eye'], 'Hay fever'),
#  (['runny', 'nose'], 'Hay fever'),
#  (['persistent', 'mouth', 'ulcer'], 'Head and neck cancer'),
#  (['lump', 'in', 'mouth'], 'Head and neck cancer'),
#  (['persistent', 'hoarseness'], 'Head and neck cancer'),
#  (['a', 'persistent', 'cough'], 'Head and neck cancer'),
#  (['lump', 'or', 'swelling', 'in', 'neck'], 'Head and neck cancer'),
#  (['shortness', 'of', 'breath'], 'Head and neck cancer'),
#  (['noisy', 'breathing'], 'Head and neck cancer'),
#  (['difficulty', 'or', 'pain', 'when', 'swallowing'], 'Head and neck cancer'),
#  (['numbness', 'in', 'face'], 'Head and neck cancer'),
#  (['drooping', 'on', 'one', 'side', 'of', 'face'], 'Head and neck cancer'),
#  (['nosebleed'], 'Head and neck cancer'),
#  (['a', 'persistent', 'blocked', 'nose'], 'Head and neck cancer'),
#  (['decreased', 'sense', 'of', 'smell'], 'Head and neck cancer'),
#  (['hearing', 'loss'], 'Head and neck cancer'),
#  (['itchy', 'scalp'], 'Head lice and nits'),
#  (['rash', 'on', 'the', 'back', 'of', 'the', 'neck'], 'Head lice and nits'),
#  (['small', 'white', 'egg', 'or', 'nit', 'in', 'the', 'hair'],
#   'Head lice and nits'),
#  (['stress'], 'Headaches'),
#  (['dehydration'], 'Headaches'),
#  (['nausea'], 'Headaches'),
#  (['vomiting'], 'Headaches'),
#  (['ncreased', 'sensitivity', 'to', 'light', 'or', 'sound'], 'Headaches'),
#  (['watering', 'or', 'red', 'eye'], 'Headaches'),
#  (['blocked', 'or', 'runny', 'nose'], 'Headaches'),
#  (['difficulty', 'hearing'], 'Hearing loss'),
#  (['misunderstanding', 'other', 'people'], 'Hearing loss'),
#  (['asking', 'people', 'to', 'repeat', 'themselves'], 'Hearing loss'),
#  (['breathlessness'], 'Heart failure'),
#  (['tiredness', 'and', 'lethargy'], 'Heart failure'),
#  (['leg', 'swelling'], 'Heart failure'),
#  (['loss', 'of', 'appetite'], 'Heart failure'),
#  (['joint', 'and', 'muscle', 'pain'], 'Hepatitis A'),
#  (['fever'], 'Hepatitis A'),
#  (['loss', 'of', 'appetite'], 'Hepatitis A'),
#  (['itchy', 'skin'], 'Hepatitis A'),
#  (['dark', 'urine'], 'Hepatitis A'),
#  (['pale', 'stool'], 'Hepatitis A'),
#  (['jaundice'], 'Hepatitis A'),
#  (['tiredness'], 'Hepatitis A'),
#  (['loss', 'of', 'appetite'], 'Hepatitis B'),
#  (['diarrhoea'], 'Hepatitis B'),
#  (['abdominal', 'pain'], 'Hepatitis B'),
#  (['tiredness'], 'Hepatitis B'),
#  (['fever'], 'Hepatitis B'),
#  (['flu'], 'Hepatitis B'),
#  (['tiredness'], 'Hepatitis C'),
#  (['flu'], 'Hepatitis C'),
#  (['loss', 'of', 'appetite'], 'Hepatitis C'),
#  (['abdominal', 'pain'], 'Hepatitis C'),
#  (['muscle', 'ache'], 'Hepatitis C'),
#  (['fever'], 'Hepatitis C'),
#  (['weak', 'diaphragm'], 'Hiatus hernia'),
#  (['pressure', 'on', 'abdomen'], 'Hiatus hernia'),
#  (['leaking', 'stomach', 'acid'], 'Hiatus hernia'),
#  (['scarring', 'on', 'stomach'], 'Hiatus hernia'),
#  (['overweight'], 'High cholesterol'),
#  (['high', 'blood', 'pressure'], 'High cholesterol'),
#  (['diabetes'], 'High cholesterol'),
#  (['stroke'], 'High cholesterol'),
#  (['heart', 'attack'], 'High cholesterol'),
#  (['fever'], 'HIV'),
#  (['swollen', 'gland'], 'HIV'),
#  (['rash'], 'HIV'),
#  (['upset', 'stomach'], 'HIV'),
#  (['headache'], 'HIV'),
#  (['muscle', 'pain'], 'HIV'),
#  (['joint', 'pain'], 'HIV'),
#  (['problem', 'in', 'movement'], "Huntington's disease"),
#  (['problem', 'in', 'cognition'], "Huntington's disease"),
#  (['mood', 'swing'], "Huntington's disease"),
#  (['personality', 'change'], "Huntington's disease"),
#  (['irritability'], "Huntington's disease"),
#  ([], "Huntington's disease"),
#  (['increased', 'thirst'], 'Hyperglycaemia (high blood sugar)'),
#  (['dry', 'mouth'], 'Hyperglycaemia (high blood sugar)'),
#  (['tiredness'], 'Hyperglycaemia (high blood sugar)'),
#  (['blurred', 'vision'], 'Hyperglycaemia (high blood sugar)'),
#  (['unintentional', 'weight', 'loss'], 'Hyperglycaemia (high blood sugar)'),
#  (['skin', 'infection'], 'Hyperglycaemia (high blood sugar)'),
#  (['thrush'], 'Hyperglycaemia (high blood sugar)'),
#  (['recurrent', 'infection'], 'Hyperglycaemia (high blood sugar)'),
#  (['bladder', 'infection'], 'Hyperglycaemia (high blood sugar)'),
#  (['frequent', 'urge', 'to', 'urinate'], 'Hyperglycaemia (high blood sugar)'),
#  (['excessive', 'sweating'], 'Hyperhidrosis'),
#  (['socially', 'withdrawn'], 'Hyperhidrosis'),
#  (['swelling', 'in', 'armpit'], 'Hyperhidrosis'),
#  (['swelling', 'in', 'palm'], 'Hyperhidrosis'),
#  (['swelling', 'in', 'groin'], 'Hyperhidrosis'),
#  (['swelling', 'in', 'sol'], 'Hyperhidrosis'),
#  (['swelling', 'in', 'face', 'and', 'chest'], 'Hyperhidrosis'),
#  (['hunger'], 'Hypoglycaemia (low blood sugar)'),
#  (['trembling'], 'Hypoglycaemia (low blood sugar)'),
#  (['shakiness'], 'Hypoglycaemia (low blood sugar)'),
#  (['sweating'], 'Hypoglycaemia (low blood sugar)'),
#  (['difficulty', 'concentrating'], 'Hypoglycaemia (low blood sugar)'),
#  (['disturbed', 'sleep'], 'Hypoglycaemia (low blood sugar)'),
#  (['confused', 'upon', 'waking'], 'Hypoglycaemia (low blood sugar)'),
#  (['shortness', 'of', 'breath'], 'Idiopathic pulmonary fibrosis'),
#  (['tiredness'], 'Idiopathic pulmonary fibrosis'),
#  (['persistent', 'dry', 'cough'], 'Idiopathic pulmonary fibrosis'),
#  (['loss', 'of', 'appetite'], 'Idiopathic pulmonary fibrosis'),
#  (['loss', 'of', 'weight'], 'Idiopathic pulmonary fibrosis'),
#  (['swollen', 'fingertip'], 'Idiopathic pulmonary fibrosis'),
#  (['clubbed', 'finger'], 'Idiopathic pulmonary fibrosis'),
#  (['red', 'sore', 'around', 'nose'], 'Impetigo'),
#  (['fever'], 'Impetigo'),
#  (['swollen', 'gland'], 'Impetigo'),
#  (['blister'], 'Impetigo'),
#  (['bloatedness'], 'Indigestion'),
#  (['belching'], 'Indigestion'),
#  (['regurgitation'], 'Indigestion'),
#  (['nausea'], 'Indigestion'),
#  (['feeling', 'full'], 'Indigestion'),
#  (['inflammation', 'in', 'toe'], 'Ingrown toenail'),
#  (['yellow', 'pu', 'from', 'toe'], 'Ingrown toenail'),
#  (['oedema'], 'Ingrown toenail'),
#  (['curling', 'of', 'nail'], 'Ingrown toenail'),
#  (['palpitation'], 'Inherited heart conditions'),
#  (['fainting'], 'Inherited heart conditions'),
#  (['blackout'], 'Inherited heart conditions'),
#  (['difficulty', 'in', 'sleeping'], 'Insomnia'),
#  (['awake', 'for', 'long', 'period'], 'Insomnia'),
#  (['not', 'feeling', 'refreshed', 'after', 'waking'], 'Insomnia'),
#  (['difficulty', 'napping'], 'Insomnia'),
#  (['difficulty', 'concentrating'], 'Insomnia'),
#  (['irritable'], 'Insomnia'),
#  (['tiredness'], 'Iron deficiency anaemia'),
#  (['lethargy'], 'Iron deficiency anaemia'),
#  (['lack', 'of', 'energy'], 'Iron deficiency anaemia'),
#  (['shortness', 'of', 'breath'], 'Iron deficiency anaemia'),
#  (['pale', 'complexion'], 'Iron deficiency anaemia'),
#  (['heart', 'palpitation'], 'Iron deficiency anaemia'),
#  (['headache'], 'Iron deficiency anaemia'),
#  (['feeling', 'itchy'], 'Iron deficiency anaemia'),
#  (['difficulty', 'swallowing'], 'Iron deficiency anaemia'),
#  (['abnormally', 'smooth', 'tongue'], 'Iron deficiency anaemia'),
#  (['hair', 'loss'], 'Iron deficiency anaemia'),
#  (['abdominal', 'pain'], 'Irritable bowel syndrome (IBS)'),
#  (['diarrhoea'], 'Irritable bowel syndrome (IBS)'),
#  (['constipation'], 'Irritable bowel syndrome (IBS)'),
#  (['bloating'], 'Irritable bowel syndrome (IBS)'),
#  (['excessive', 'flatulence'], 'Irritable bowel syndrome (IBS)'),
#  (['lethargy'], 'Irritable bowel syndrome (IBS)'),
#  (['heartburn'], 'Irritable bowel syndrome (IBS)'),
#  (['cramping'], 'Irritable bowel syndrome (IBS)'),
#  (['slightly', 'higher', 'temperature'], 'Irritable hip'),
#  (['pain', 'in', 'the', 'knee'], 'Irritable hip'),
#  (['thigh', 'pain'], 'Irritable hip'),
#  (['estricted', 'movement', 'in', 'hip', 'joint'], 'Irritable hip'),
#  (['limping'], 'Irritable hip'),
#  (['hip', 'pain'], 'Irritable hip'),
#  (['redness'], 'Itching'),
#  (['leathery', 'or', 'scaly', 'patch'], 'Itching'),
#  (['scratch', 'mark'], 'Itching'),
#  (['blister'], 'Itching'),
#  (['cracked', 'skin'], 'Itching'),
#  (['itchy', 'skin'], 'Itching'),
#  (['itchness', 'all', 'over', 'body'], 'Itching'),
#  (['dry', 'skin'], 'Itching'),
#  (['persistent', 'itch'], 'Itching'),
#  (['persistent', 'anal', 'itch'], 'Itchy bottom'),
#  (['anal', 'bleeding'], 'Itchy bottom'),
#  (['stool', 'leakage'], 'Itchy bottom'),
#  (['severe', 'rectal', 'itch'], 'Itchy bottom'),
#  (['itchness', 'in', 'bottom'], 'Itchy bottom'),
#  (['uncomfortable', 'swelling'], "Kaposi's sarcoma"),
#  (['nausea'], "Kaposi's sarcoma"),
#  (['vomiting'], "Kaposi's sarcoma"),
#  ([], "Kaposi's sarcoma"),
#  (['coughing', 'up', 'blood'], "Kaposi's sarcoma"),
#  (['chest', 'pain'], "Kaposi's sarcoma"),
#  (['stomach', 'pain'], "Kaposi's sarcoma"),
#  (['pu', 'in', 'kidney'], 'Kidney infection'),
#  (['shivering'], 'Kidney infection'),
#  (['pain', 'in', 'the', 'back'], 'Kidney infection'),
#  (['painful', 'urination'], 'Kidney infection'),
#  (['fever'], 'Kidney infection'),
#  (['persistent', 'ache', 'in', 'lower', 'back'], 'Kidney stones'),
#  (['period', 'of', 'intense', 'pain'], 'Kidney stones'),
#  (['nausea'], 'Kidney stones'),
#  (['pain', 'while', 'urination'], 'Kidney stones'),
#  (['blood', 'in', 'urine'], 'Kidney stones'),
#  (['gfrequent', 'urge', 'to', 'urinate'], 'Kidney stones'),
#  (['restlessness'], 'Kidney stones'),
#  (['thank', 'you', 'goodbye'], 'Goodbye'),
#  (['see', 'you'], 'Goodbye'),
#  (['bye'], 'Goodbye'),
#  (['goodbye'], 'Goodbye')]

# %%
import pickle

# %%
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# %%
X, y = [], []
for word_patterns, tag in documents:
    bag = [1 if w in word_patterns else 0 for w in words]

    onehot = [0]*len(classes)
    onehot[classes.index(tag)] = 1

    X.append(bag)
    y.append(onehot)

X = np.array(X, dtype=np.float32)             
y = np.array(y, dtype=np.float32)             

idx = np.arange(len(X))
np.random.shuffle(idx)
train_x = X[idx]
train_y = y[idx]

print(train_x.shape, train_y.shape)
# Out:
# (551, 497) (551, 98)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential()
model.add(Dense(256, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)

model.save("chatbot_model.keras", hist)
print("Done!")
# Out:
# Epoch 1/200
# C:\Users\Ankit Regmi\anaconda3\envs\tf_notebook\lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\Ankit Regmi\anaconda3\envs\tf_notebook\lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0109 - loss: 4.5904
# Epoch 2/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0163 - loss: 4.5516
# Epoch 3/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0327 - loss: 4.5119
# Epoch 4/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0290 - loss: 4.4802
# Epoch 5/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0417 - loss: 4.4365
# Epoch 6/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0490 - loss: 4.3805
# Epoch 7/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0672 - loss: 4.3186
# Epoch 8/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0780 - loss: 4.2308
# Epoch 9/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0907 - loss: 4.1182
# Epoch 10/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0962 - loss: 3.9870
# Epoch 11/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1579 - loss: 3.8486
# Epoch 12/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1815 - loss: 3.6889
# Epoch 13/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1978 - loss: 3.4844
# Epoch 14/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2450 - loss: 3.3099
# Epoch 15/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2396 - loss: 3.1219
# Epoch 16/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2958 - loss: 2.8930
# Epoch 17/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3049 - loss: 2.8269
# Epoch 18/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3721 - loss: 2.5657
# Epoch 19/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3811 - loss: 2.4991
# Epoch 20/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4029 - loss: 2.3208
# Epoch 21/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4265 - loss: 2.2226
# Epoch 22/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4592 - loss: 2.1491
# Epoch 23/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4574 - loss: 2.0355
# Epoch 24/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5100 - loss: 1.8584
# Epoch 25/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5118 - loss: 1.8650
# Epoch 26/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5100 - loss: 1.8019
# Epoch 27/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5390 - loss: 1.6882
# Epoch 28/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5699 - loss: 1.6102
# Epoch 29/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5953 - loss: 1.5406
# Epoch 30/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5808 - loss: 1.5208
# Epoch 31/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6062 - loss: 1.4808
# Epoch 32/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6152 - loss: 1.3988
# Epoch 33/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6044 - loss: 1.3946
# Epoch 34/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6461 - loss: 1.2605
# Epoch 35/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6171 - loss: 1.3349
# Epoch 36/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6207 - loss: 1.3421
# Epoch 37/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6207 - loss: 1.2784
# Epoch 38/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6552 - loss: 1.2048
# Epoch 39/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6552 - loss: 1.2153
# Epoch 40/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6425 - loss: 1.1858
# Epoch 41/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6661 - loss: 1.2062
# Epoch 42/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6552 - loss: 1.1707
# Epoch 43/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6642 - loss: 1.1369
# Epoch 44/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6770 - loss: 1.1009
# Epoch 45/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7060 - loss: 1.0853
# Epoch 46/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6987 - loss: 1.0243
# Epoch 47/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6915 - loss: 1.0811
# Epoch 48/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7096 - loss: 0.9741
# Epoch 49/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6806 - loss: 1.0815
# Epoch 50/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 5180s 47s/step - accuracy: 0.6842 - loss: 1.0701
# Epoch 51/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6806 - loss: 1.0331
# Epoch 52/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6915 - loss: 1.0639
# Epoch 53/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6806 - loss: 1.0372
# Epoch 54/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6878 - loss: 1.0227
# Epoch 55/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6969 - loss: 0.9657
# Epoch 56/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6824 - loss: 1.0062
# Epoch 57/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6842 - loss: 0.9754
# Epoch 58/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7223 - loss: 0.9702
# Epoch 59/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6842 - loss: 1.0331
# Epoch 60/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6969 - loss: 0.9313
# Epoch 61/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7151 - loss: 0.9257
# Epoch 62/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7223 - loss: 0.9323
# Epoch 63/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7024 - loss: 0.9629
# Epoch 64/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6987 - loss: 0.9249
# Epoch 65/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7169 - loss: 0.8640
# Epoch 66/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7114 - loss: 0.8934
# Epoch 67/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6915 - loss: 0.9456
# Epoch 68/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7441 - loss: 0.8304
# Epoch 69/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7332 - loss: 0.8767
# Epoch 70/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7314 - loss: 0.8502
# Epoch 71/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7241 - loss: 0.8814
# Epoch 72/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7169 - loss: 0.9354
# Epoch 73/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7278 - loss: 0.8234
# Epoch 74/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7132 - loss: 0.8927
# Epoch 75/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7187 - loss: 0.8620
# Epoch 76/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7278 - loss: 0.8231
# Epoch 77/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7278 - loss: 0.8931
# Epoch 78/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7223 - loss: 0.9252
# Epoch 79/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7205 - loss: 0.8698
# Epoch 80/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7278 - loss: 0.8609
# Epoch 81/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7151 - loss: 0.8751
# Epoch 82/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.7824
# Epoch 83/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7332 - loss: 0.8431
# Epoch 84/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.7915
# Epoch 85/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7151 - loss: 0.8413
# Epoch 86/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7260 - loss: 0.8582
# Epoch 87/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7151 - loss: 0.8387
# Epoch 88/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.7849
# Epoch 89/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7169 - loss: 0.8204
# Epoch 90/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.7799
# Epoch 91/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7205 - loss: 0.8298
# Epoch 92/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7332 - loss: 0.7766
# Epoch 93/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7241 - loss: 0.8248
# Epoch 94/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7514 - loss: 0.7710
# Epoch 95/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.7865
# Epoch 96/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7514 - loss: 0.7330
# Epoch 97/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - loss: 0.8163
# Epoch 98/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7132 - loss: 0.8448
# Epoch 99/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7441 - loss: 0.8325
# Epoch 100/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - loss: 0.7587
# Epoch 101/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7368 - loss: 0.7918
# Epoch 102/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.7391
# Epoch 103/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7314 - loss: 0.7996
# Epoch 104/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7096 - loss: 0.8142
# Epoch 105/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - loss: 0.7521
# Epoch 106/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7314 - loss: 0.7855
# Epoch 107/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7314 - loss: 0.7655
# Epoch 108/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7659 - loss: 0.7241
# Epoch 109/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7423 - loss: 0.7183
# Epoch 110/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7132 - loss: 0.8031
# Epoch 111/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7477 - loss: 0.7707
# Epoch 112/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7332 - loss: 0.7711
# Epoch 113/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.7501
# Epoch 114/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.7662
# Epoch 115/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7296 - loss: 0.7400
# Epoch 116/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7495 - loss: 0.7624
# Epoch 117/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.7364
# Epoch 118/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - loss: 0.7938
# Epoch 119/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7187 - loss: 0.7097
# Epoch 120/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7514 - loss: 0.7062
# Epoch 121/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - loss: 0.7323
# Epoch 122/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7296 - loss: 0.7652
# Epoch 123/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7405 - loss: 0.7116
# Epoch 124/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7641 - loss: 0.6930
# Epoch 125/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.6903
# Epoch 126/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7441 - loss: 0.7736
# Epoch 127/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7495 - loss: 0.6561
# Epoch 128/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7368 - loss: 0.6984
# Epoch 129/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7532 - loss: 0.7286
# Epoch 130/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7550 - loss: 0.7369
# Epoch 131/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7568 - loss: 0.7269
# Epoch 132/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7495 - loss: 0.7204
# Epoch 133/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7223 - loss: 0.7921
# Epoch 134/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.7370
# Epoch 135/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7495 - loss: 0.6939
# Epoch 136/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7441 - loss: 0.7295
# Epoch 137/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7477 - loss: 0.7244
# Epoch 138/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7368 - loss: 0.7031
# Epoch 139/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7550 - loss: 0.7156
# Epoch 140/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - loss: 0.7366
# Epoch 141/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7405 - loss: 0.7219
# Epoch 142/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7514 - loss: 0.6899
# Epoch 143/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7786 - loss: 0.6614
# Epoch 144/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7423 - loss: 0.7249
# Epoch 145/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7550 - loss: 0.6716
# Epoch 146/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7368 - loss: 0.7332
# Epoch 147/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7314 - loss: 0.6823
# Epoch 148/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7677 - loss: 0.6900
# Epoch 149/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7604 - loss: 0.6934
# Epoch 150/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7514 - loss: 0.6854
# Epoch 151/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.6679
# Epoch 152/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7550 - loss: 0.6872
# Epoch 153/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7550 - loss: 0.7061
# Epoch 154/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7586 - loss: 0.6710
# Epoch 155/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7641 - loss: 0.6448
# Epoch 156/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7586 - loss: 0.6492
# Epoch 157/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7387 - loss: 0.7082
# Epoch 158/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7296 - loss: 0.7437
# Epoch 159/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7332 - loss: 0.7189
# Epoch 160/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.7081
# Epoch 161/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7368 - loss: 0.7155
# Epoch 162/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7677 - loss: 0.6834
# Epoch 163/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7260 - loss: 0.7328
# Epoch 164/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7368 - loss: 0.6801
# Epoch 165/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7731 - loss: 0.6594
# Epoch 166/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7713 - loss: 0.6657
# Epoch 167/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7586 - loss: 0.6628
# Epoch 168/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.6750
# Epoch 169/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7604 - loss: 0.6620
# Epoch 170/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7550 - loss: 0.6993
# Epoch 171/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7659 - loss: 0.6587
# Epoch 172/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7350 - loss: 0.7050
# Epoch 173/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7550 - loss: 0.6741
# Epoch 174/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7677 - loss: 0.6770
# Epoch 175/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7604 - loss: 0.6854
# Epoch 176/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7368 - loss: 0.6953
# Epoch 177/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7495 - loss: 0.6795
# Epoch 178/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7532 - loss: 0.6781
# Epoch 179/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7260 - loss: 0.7660
# Epoch 180/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7731 - loss: 0.6471
# Epoch 181/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7604 - loss: 0.6663
# Epoch 182/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7441 - loss: 0.6982
# Epoch 183/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7568 - loss: 0.6981
# Epoch 184/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7405 - loss: 0.6929
# Epoch 185/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7677 - loss: 0.6440
# Epoch 186/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7713 - loss: 0.6445
# Epoch 187/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7441 - loss: 0.6925
# Epoch 188/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7441 - loss: 0.6939
# Epoch 189/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7532 - loss: 0.6535
# Epoch 190/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7514 - loss: 0.6778
# Epoch 191/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7368 - loss: 0.6780
# Epoch 192/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.6473
# Epoch 193/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7550 - loss: 0.6415
# Epoch 194/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7568 - loss: 0.6925
# Epoch 195/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7477 - loss: 0.6581
# Epoch 196/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7495 - loss: 0.6562
# Epoch 197/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7405 - loss: 0.7085
# Epoch 198/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7550 - loss: 0.6334
# Epoch 199/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7405 - loss: 0.7168
# Epoch 200/200
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7477 - loss: 0.6285
# Done!
